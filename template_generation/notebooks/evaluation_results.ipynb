# %%
import pandas as pd
import os

# %%
kt_results_base_path = "/Users/Maria.Tigina/PycharmProjects/agents-eval-data/gen_templates_result_kt"

# %%
pd.read_csv(os.path.join(kt_results_base_path, "gpt-4-vanilla.csv"))
# Out:
#    id                                    full_name  \
# 0   5   arkivanov/decompose-multiplatform-template
# 1  40                mpetuska/template-kmp-library
# 2   9     christian-draeger/basic-selenium-project
# 3  26  JetBrains/intellij-platform-plugin-template
# 4  29                  jmfayard/kotlin-cli-starter
# 5  58        team-dodn/spring-boot-kotlin-template
# 6  66                   ximedes/ktor-authorization
#
#                                 name              owner        time  \
# 0   decompose-multiplatform-template          arkivanov   54.116785
# 1               template-kmp-library           mpetuska    5.094152
# 2             basic-selenium-project  christian-draeger   24.287597
# 3  intellij-platform-plugin-template          JetBrains   34.015936
# 4                 kotlin-cli-starter           jmfayard   65.441221
# 5        spring-boot-kotlin-template          team-dodn  109.641799
# 6                 ktor-authorization            ximedes   50.232280
#
# ...

# %%
pd.read_csv(os.path.join(kt_results_base_path, "gpt-4-vanilla-cost-metrics.csv"))
# Out:
#    id                                    full_name              owner  \
# 0   5   arkivanov/decompose-multiplatform-template          arkivanov
# 1  40                mpetuska/template-kmp-library           mpetuska
# 2   9     christian-draeger/basic-selenium-project  christian-draeger
# 3  26  JetBrains/intellij-platform-plugin-template          JetBrains
# 4  29                  jmfayard/kotlin-cli-starter           jmfayard
# 5  58        team-dodn/spring-boot-kotlin-template          team-dodn
# 6  66                   ximedes/ktor-authorization            ximedes
#
#                                 name        time  gen_files_count  \
# 0   decompose-multiplatform-template   54.116785                7
# 1               template-kmp-library    5.094152                1
# 2             basic-selenium-project   24.287597                2
# 3  intellij-platform-plugin-template   34.015936                1
# 4                 kotlin-cli-starter   65.441221                7
# ...

# %% [markdown]
# # GPT 3.5

# %%
pd.read_csv(os.path.join(kt_results_base_path, "gpt-3-5-planning.csv"))
# Out:
#    id                                    full_name  \
# 0   5   arkivanov/decompose-multiplatform-template
# 1  40                mpetuska/template-kmp-library
# 2   9     christian-draeger/basic-selenium-project
# 3  26  JetBrains/intellij-platform-plugin-template
# 4  29                  jmfayard/kotlin-cli-starter
# 5  58        team-dodn/spring-boot-kotlin-template
# 6  66                   ximedes/ktor-authorization
#
#                                 name              owner       time  \
# 0   decompose-multiplatform-template          arkivanov  22.683797
# 1               template-kmp-library           mpetuska  54.351388
# 2             basic-selenium-project  christian-draeger  32.734450
# 3  intellij-platform-plugin-template          JetBrains  35.592742
# 4                 kotlin-cli-starter           jmfayard  21.523763
# 5        spring-boot-kotlin-template          team-dodn  24.968740
# 6                 ktor-authorization            ximedes  27.956571
#
# ...

# %%
pd.read_csv(os.path.join(kt_results_base_path, "gpt-3-5-planning-quality-metrics.csv"))
# Out:
#    id                                    full_name              owner  \
# 0  40                mpetuska/template-kmp-library           mpetuska
# 1   9     christian-draeger/basic-selenium-project  christian-draeger
# 2  26  JetBrains/intellij-platform-plugin-template          JetBrains
# 3  29                  jmfayard/kotlin-cli-starter           jmfayard
# 4  58        team-dodn/spring-boot-kotlin-template          team-dodn
# 5  66                   ximedes/ktor-authorization            ximedes
#
#                                 name          bleu    rouge1    rouge2  \
# 0               template-kmp-library  1.907610e-30  0.019070  0.006510
# 1             basic-selenium-project  4.041210e-18  0.052270  0.033007
# 2  intellij-platform-plugin-template  3.274308e-12  0.069446  0.044406
# 3                 kotlin-cli-starter  5.552566e-79  0.013352  0.008903
# 4        spring-boot-kotlin-template  4.759329e-37  0.022348  0.007033
# ...

# %%
pd.read_csv(os.path.join(kt_results_base_path, "gpt-3-5-planning-cost-metrics.csv"))
# Out:
#    id                                    full_name              owner  \
# 0   5   arkivanov/decompose-multiplatform-template          arkivanov
# 1  40                mpetuska/template-kmp-library           mpetuska
# 2   9     christian-draeger/basic-selenium-project  christian-draeger
# 3  26  JetBrains/intellij-platform-plugin-template          JetBrains
# 4  29                  jmfayard/kotlin-cli-starter           jmfayard
# 5  58        team-dodn/spring-boot-kotlin-template          team-dodn
# 6  66                   ximedes/ktor-authorization            ximedes
#
#                                 name       time  gen_files_count  \
# 0   decompose-multiplatform-template  22.683797                5
# 1               template-kmp-library  54.351388               13
# 2             basic-selenium-project  32.734450                7
# 3  intellij-platform-plugin-template  35.592742                8
# 4                 kotlin-cli-starter  21.523763                4
# ...

# %% [markdown]
# # GPT 4

# %%
pd.read_csv(os.path.join(kt_results_base_path, "gpt-4-planning.csv"))
# Out:
#    id                                    full_name  \
# 0   5   arkivanov/decompose-multiplatform-template
# 1  40                mpetuska/template-kmp-library
# 2   9     christian-draeger/basic-selenium-project
# 3  26  JetBrains/intellij-platform-plugin-template
# 4  29                  jmfayard/kotlin-cli-starter
# 5  58        team-dodn/spring-boot-kotlin-template
# 6  66                   ximedes/ktor-authorization
#
#                                 name              owner        time  \
# 0   decompose-multiplatform-template          arkivanov  103.012096
# 1               template-kmp-library           mpetuska  107.426855
# 2             basic-selenium-project  christian-draeger   80.290604
# 3  intellij-platform-plugin-template          JetBrains   85.327181
# 4                 kotlin-cli-starter           jmfayard   62.914262
# 5        spring-boot-kotlin-template          team-dodn   96.656111
# 6                 ktor-authorization            ximedes   97.454844
#
# ...

# %%
pd.read_csv(os.path.join(kt_results_base_path, "gpt-4-planning-quality-metrics.csv"))
# Out:
#    id                                    full_name              owner  \
# 0  40                mpetuska/template-kmp-library           mpetuska
# 1   9     christian-draeger/basic-selenium-project  christian-draeger
# 2  26  JetBrains/intellij-platform-plugin-template          JetBrains
# 3  29                  jmfayard/kotlin-cli-starter           jmfayard
# 4  58        team-dodn/spring-boot-kotlin-template          team-dodn
# 5  66                   ximedes/ktor-authorization            ximedes
#
#                                 name          bleu    rouge1    rouge2  \
# 0               template-kmp-library  2.593933e-25  0.024491  0.005118
# 1             basic-selenium-project  6.170400e-14  0.057309  0.027353
# 2  intellij-platform-plugin-template  1.688914e-17  0.039664  0.022875
# 3                 kotlin-cli-starter  2.466652e-43  0.020676  0.013458
# 4        spring-boot-kotlin-template  2.990684e-08  0.103341  0.049176
# ...

# %%
pd.read_csv(os.path.join(kt_results_base_path, "gpt-4-planning-cost-metrics.csv"))
# Out:
#    id                                    full_name              owner  \
# 0   5   arkivanov/decompose-multiplatform-template          arkivanov
# 1  40                mpetuska/template-kmp-library           mpetuska
# 2   9     christian-draeger/basic-selenium-project  christian-draeger
# 3  26  JetBrains/intellij-platform-plugin-template          JetBrains
# 4  29                  jmfayard/kotlin-cli-starter           jmfayard
# 5  58        team-dodn/spring-boot-kotlin-template          team-dodn
# 6  66                   ximedes/ktor-authorization            ximedes
#
#                                 name        time  gen_files_count  \
# 0   decompose-multiplatform-template  103.012096                7
# 1               template-kmp-library  107.426855               10
# 2             basic-selenium-project   80.290604                4
# 3  intellij-platform-plugin-template   85.327181                6
# 4                 kotlin-cli-starter   62.914262                4
# ...
